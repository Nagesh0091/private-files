# %% [markdown]
# # 🎯 Feature Creation
# - Boosting Model Power with Smart Features!
#
# Feature Creation is the art of generating new variables (features) from the existing data to enhance a model’s predictive performance

# %%
# DATA LOADING:
import pandas as pd
DATA=pd.read_csv(r"C:\Users\Nagesh Agrawal\OneDrive\Desktop\EDA\DATA\corrected_data_type.csv")

# %%
DATA
# Out:
#     Order_ID  Order_Date  Quantity  Discount   Sales  Postal_Code Product_ID  \
# 0       1001  2022-01-10         5      0.10  500.75       560001      P-001
# 1       1002  2022-01-12         3      0.05  450.00       110001      P-002
# 2       1003  2022-01-13         2      0.00  350.00       700014      P-003
# 3       1004  2022-01-15         4      0.20  450.00       500081      P-004
# 4       1005  2022-01-18         3       NaN  480.50       560002      P-005
# 5       1006  2022-01-20         6      0.15  600.00       110002      P-006
# 6       1007  2022-01-22         5      0.05  500.00       700015      P-007
# 7       1008  2022-01-24         4      0.10  550.25       500082      P-008
# 8       1009  2022-01-25         5      0.00  475.00       560003      P-009
# 9       1010         NaN         6      0.10     NaN       110003      P-010
# 10      1011  2022-01-27         7      0.20  610.00       700016      P-011
# ...

# %% [markdown]
# ### TO CALCULATE HOW MUCH THE DISCOUNT AMOUNT IS??
# DISCOUNT AMOUNT = DISCOUNT PERCENTAGE/100 * AMOUNT

# %%
# BUT THE DISCOUNT VALUES IS ALREADY DIVIDED BY 100
# DATA["DISCOUNT_AMOUNT"]=DATA["Discount"]*DATA["Sales"]
DATA.insert(5, "DISCOUNT_AMOUNT", DATA["Discount"] * DATA["Sales"])

# %%
DATA
# Out:
#     Order_ID  Order_Date  Quantity  Discount   Sales  DISCOUNT_AMOUNT  \
# 0       1001  2022-01-10         5      0.10  500.75           50.075
# 1       1002  2022-01-12         3      0.05  450.00           22.500
# 2       1003  2022-01-13         2      0.00  350.00            0.000
# 3       1004  2022-01-15         4      0.20  450.00           90.000
# 4       1005  2022-01-18         3       NaN  480.50              NaN
# 5       1006  2022-01-20         6      0.15  600.00           90.000
# 6       1007  2022-01-22         5      0.05  500.00           25.000
# 7       1008  2022-01-24         4      0.10  550.25           55.025
# 8       1009  2022-01-25         5      0.00  475.00            0.000
# 9       1010         NaN         6      0.10     NaN              NaN
# 10      1011  2022-01-27         7      0.20  610.00          122.000
# 11      1012  2022-01-29         3      0.05  490.00           24.500
# ...
