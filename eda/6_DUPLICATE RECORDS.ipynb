# %% [markdown]
# # **DUPLICATES RECORDS**

# %% [markdown]
# #### DUPLICATE RECORDS REFERS TO ENTRIES IN DATASET THAT ARE IDENTICAL OR VERY SIMILAR TO ONE ANOTHER.

# %% [markdown]
# Sure! Here's your updated and catchy version with the solution added:
#
# ---
#
# 🎯 **Effect of Duplicates on Mean** 🎯
# > **"The mean is often seen as the heart of the dataset."**
#
# 📌 It **summarizes the central tendency**, giving us a single value to represent the entire data.
# BUT... it **fails** when the data is **unfair or extreme**!
#
# 🚫 **When does the mean mislead us?**
# - ⚠️ **Outliers**: A few extreme values can drag the mean too high or too low.
# - 📉 **Skewed Data**: If the data leans heavily to one side, the mean gets pulled away from the true center.
# - 🔁 **Duplicates**: Repeating values — especially extreme ones — can **magnify** the distortion!
#
# ✅ **There’s only one solution:**
# 🧹 **Remove duplicate records** to ensure the mean truly represents your data!
#
# ---
#
# Let me know if you'd like this turned into a poster-style image or presentation slide!

# %%
# LOADING DATA:
import pandas as pd
DATA=pd.read_csv(r"C:\Users\Nagesh Agrawal\OneDrive\Desktop\EDA\DATA\CLEAN_DATA.csv")

# %%
DATA
# Out:
#                       event_time        event_type  product_id  \
# 0        2019-12-01 00:00:00 UTC  remove_from_cart     5712790
# 1        2019-12-01 00:00:00 UTC              view     5764655
# 2        2019-12-01 00:00:02 UTC              cart        4958
# 3        2019-12-01 00:00:05 UTC              view     5848413
# 4        2019-12-01 00:00:07 UTC              view     5824148
# ...                          ...               ...         ...
# 3532502  2019-12-31 23:59:39 UTC              view     5683350
# 3532503  2019-12-31 23:59:46 UTC              view     5888097
# 3532504  2019-12-31 23:59:51 UTC              view       59975
# 3532505  2019-12-31 23:59:52 UTC              view     5775982
# 3532506  2019-12-31 23:59:57 UTC              view     5635090
#
#                  category_id      brand   price    user_id  \
# 0        1487580005268456287      f.o.x    6.27  576802932
# 1        1487580005411062629        cnd   29.05  412120092
# ...

# %% [markdown]
# # IDENTIFY DUPLICATES

# %%
# DATA[DATA.duplicated()]
#DATA[DATA.duplicated(keep="first")]# keep first record as original
#DATA[DATA.duplicated(keep="last")]# keep last record as original
DATA[DATA.duplicated(keep=False)]# dont keep any record as original..
# Out:
#                       event_time        event_type  product_id  \
# 36       2019-12-01 00:01:52 UTC              cart     5700046
# 37       2019-12-01 00:01:52 UTC              cart     5700046
# 54       2019-12-01 00:02:49 UTC              cart     5693501
# 55       2019-12-01 00:02:49 UTC              cart     5693501
# 59       2019-12-01 00:03:08 UTC  remove_from_cart     5839671
# ...                          ...               ...         ...
# 3532393  2019-12-31 23:48:49 UTC  remove_from_cart     5917159
# 3532405  2019-12-31 23:50:26 UTC  remove_from_cart     5809910
# 3532406  2019-12-31 23:50:26 UTC  remove_from_cart     5809910
# 3532481  2019-12-31 23:57:22 UTC  remove_from_cart     5893695
# 3532482  2019-12-31 23:57:22 UTC  remove_from_cart     5893695
#
#                  category_id      brand  price    user_id  \
# 36       1487580009286598681     runail   0.40  576802932
# 37       1487580009286598681     runail   0.40  576802932
# ...

# %% [markdown]
# # REMOVEING DUPLICATES

# %%
# DATA.drop_duplicates()

# %% [markdown]
# # **BUT WHAT I OBSERVED HERE IN DATA**
#
# 🛒 **User orders multiple quantities** (e.g., 10 pieces) of the **same product** at once →
# 📦 The system logs the **same product 10 times**, **once per unit**.

# %%
DATA
# Out:
#                       event_time        event_type  product_id  \
# 0        2019-12-01 00:00:00 UTC  remove_from_cart     5712790
# 1        2019-12-01 00:00:00 UTC              view     5764655
# 2        2019-12-01 00:00:02 UTC              cart        4958
# 3        2019-12-01 00:00:05 UTC              view     5848413
# 4        2019-12-01 00:00:07 UTC              view     5824148
# ...                          ...               ...         ...
# 3532502  2019-12-31 23:59:39 UTC              view     5683350
# 3532503  2019-12-31 23:59:46 UTC              view     5888097
# 3532504  2019-12-31 23:59:51 UTC              view       59975
# 3532505  2019-12-31 23:59:52 UTC              view     5775982
# 3532506  2019-12-31 23:59:57 UTC              view     5635090
#
#                  category_id      brand   price    user_id  \
# 0        1487580005268456287      f.o.x    6.27  576802932
# 1        1487580005411062629        cnd   29.05  412120092
# ...

# %%
# Group by key columns and count frequency as quantity
df_quantity = DATA.groupby(
    ['event_time', 'event_type', 'product_id', 'category_id', 'brand', 'price','user_id','user_session']
).size().reset_index(name='quantity')

# %%
df_quantity["quantity"].unique()
# Out:
# array([ 1,  2,  4,  3,  5,  6,  9, 10,  7,  8, 12, 11, 13, 20, 19],
#       dtype=int64)

# %%
df_quantity
# Out:
#                       event_time        event_type  product_id  \
# 0        2019-12-01 00:00:00 UTC  remove_from_cart     5712790
# 1        2019-12-01 00:00:00 UTC              view     5764655
# 2        2019-12-01 00:00:02 UTC              cart        4958
# 3        2019-12-01 00:00:05 UTC              view     5848413
# 4        2019-12-01 00:00:07 UTC              view     5824148
# ...                          ...               ...         ...
# 3348707  2019-12-31 23:59:39 UTC              view     5683350
# 3348708  2019-12-31 23:59:46 UTC              view     5888097
# 3348709  2019-12-31 23:59:51 UTC              view       59975
# 3348710  2019-12-31 23:59:52 UTC              view     5775982
# 3348711  2019-12-31 23:59:57 UTC              view     5635090
#
#                  category_id      brand   price    user_id  \
# 0        1487580005268456287      f.o.x    6.27  576802932
# 1        1487580005411062629        cnd   29.05  412120092
# ...

# %%
# df_quantity.to_csv(r"DATA\DUPLICATES_REMOVED_DATA.csv",index=False)
