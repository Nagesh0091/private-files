# %% [markdown]
# ---
#
# # 🔍 **CORRELATION vs PPS (Predictive Power Score)**
#
# ## 🎯 **What’s the Core Difference?**
#
# 👉 The **main difference** lies in **what they measure** and **how they are used**.
#
# ---
#
# ## 📉 **CORRELATION**
#
# > **Measures:** *Linear relationship between two numerical variables*
#
# 📏 **Range:** `-1` to `1`
#
# * 🔼 **+1** → Strong **positive** linear relationship
# * 🔽 **-1** → Strong **negative** linear relationship
# * 0️⃣ **0** → No linear relationship
#
# 🧪 **Used when:** You want to check *how closely two numeric variables move together in a straight-line pattern*.
#
# ---
#
# ## 🤖 **PPS (Predictive Power Score)**
#
# > **Measures:** *Predictive power of one variable to predict another*
# > 🧩 **Works with:** Numerical **or** Categorical variables
#
# 📏 **Range:** `0` to `1`
#
# * 0️⃣ **0** → No predictive power
# * 💯 **1** → Perfect predictive power
# * 🔁 **Handles:** Non-linear, complex, or hidden patterns in data
#
# ✅ **More flexible:** Works on **linear or non-linear** data and supports **mixed variable types**
#
# ---
#
# ## 🧠 **Summary at a Glance**
#
# | Feature               | 📉 Correlation        | 🎯 PPS                       |
# | --------------------- | --------------------- | ---------------------------- |
# | Measures              | Linear relationship   | Predictive power             |
# | Data Type             | Numerical only        | Numerical & Categorical      |
# | Range                 | -1 to 1               | 0 to 1                       |
# | Handles Non-linearity | ❌ No                  | ✅ Yes                        |
# | Use Case              | Relationship analysis | Prediction strength analysis |
#
# ---
#
# ✨ **Choose Correlation for** understanding *linear trends*.
#
# 🚀 **Use PPS when** predicting outcomes with *any kind of data*!
#
# ---

# %% [markdown]
# ---
#
# # 🔁 **CORRELATION vs 🎯 PPS: DIRECTION MATTERS!**
#
# ---
#
# ## 📉 **CORRELATION – Symmetric 🔄**
#
# > ✅ The relationship is **the same in both directions**
# > 🔁 **A ↔ B** = **B ↔ A**
#
# ### 💡 Example:
#
# If A increases when B increases,
# then B also increases when A increases — *same strength both ways!*
#
# ---
#
# ## 🤖 **PPS (Predictive Power Score) – Asymmetric 🔀**
#
# > ❌ The relationship **can change direction**
# > 🔀 **A ➡ B** ≠ **B ➡ A**
#
# ### 💡 Example:
#
# A might strongly predict B,
# but B might be a weak predictor for A — *direction matters!*
#
# ---
#
# ## 🧠 **Quick Recap**
#
# | Feature         | 📉 **Correlation**            | 🎯 **PPS**                     |
# | --------------- | ----------------------------- | ------------------------------ |
# | Directionality  | 🔁 Symmetric                  | 🔀 Asymmetric                  |
# | A vs B Relation | Same both ways                | Can differ based on direction  |
# | Use Case        | Measuring mutual relationship | Evaluating prediction strength |
#
# ---
#
# ✨ **Remember:**
# Use **Correlation** when the relationship is mutual.
# Use **PPS** when *predictive direction* matters!
#
# ---

# %%
# LOADING DATA:
import pandas as pd 
DATA=pd.read_csv(r"C:\Users\Nagesh Agrawal\OneDrive\Desktop\EDA\DATA\PPS DATASET.csv")
DATA
# Out:
# c:\Users\Nagesh Agrawal\OneDrive\Desktop\EDA\.venv\lib\site-packages\IPython\core\formatters.py:406: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
! pip install ppscore
# Out:
# Requirement already satisfied: ppscore in c:\users\nagesh agrawal\onedrive\desktop\eda\.venv\lib\site-packages (1.3.0)
# Collecting pandas<2.0.0,>=1.0.0 (from ppscore)
#   Using cached pandas-1.5.3-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: scikit-learn<2.0.0,>=0.20.2 in c:\users\nagesh agrawal\onedrive\desktop\eda\.venv\lib\site-packages (from ppscore) (1.6.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\nagesh agrawal\onedrive\desktop\eda\.venv\lib\site-packages (from pandas<2.0.0,>=1.0.0->ppscore) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nagesh agrawal\onedrive\desktop\eda\.venv\lib\site-packages (from pandas<2.0.0,>=1.0.0->ppscore) (2025.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\nagesh agrawal\onedrive\desktop\eda\.venv\lib\site-packages (from pandas<2.0.0,>=1.0.0->ppscore) (2.2.5)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\nagesh agrawal\onedrive\desktop\eda\.venv\lib\site-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\nagesh agrawal\onedrive\desktop\eda\.venv\lib\site-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\nagesh agrawal\onedrive\desktop\eda\.venv\lib\site-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\nagesh agrawal\onedrive\desktop\eda\.venv\lib\site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.0.0->ppscore) (1.17.0)
# Using cached pandas-1.5.3-cp310-cp310-win_amd64.whl (10.4 MB)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
# Successfully installed pandas-1.5.3
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Nagesh Agrawal\OneDrive\Desktop\EDA\.venv\Lib\site-packages\~andas.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Nagesh Agrawal\OneDrive\Desktop\EDA\.venv\Lib\site-packages\~-ndas'.
#   You can safely remove it manually.

# %%
import ppscore as pps
# pyhton 3.10 will work we need to create venv

# %%
pps.score(DATA,"SepalLengthCm","PetalLengthCm")
# Out:
# {'x': 'SepalLengthCm',
#  'y': 'PetalLengthCm',
#  'ppscore': np.float64(0.5505748783284862),
#  'case': 'regression',
#  'is_valid_score': True,
#  'metric': 'mean absolute error',
#  'baseline_score': 1.488,
#  'model_score': np.float64(0.6687445810472126),
#  'model': DecisionTreeRegressor()}

# %%
pps_matrix=pps.matrix(DATA)

# %%
PPS_DATAFRAME=pd.DataFrame(pps_matrix)

# %%
PPS_DATAFRAME
# Out:
# c:\Users\Nagesh Agrawal\OneDrive\Desktop\EDA\.venv\lib\site-packages\IPython\core\formatters.py:406: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
# c:\Users\Nagesh Agrawal\OneDrive\Desktop\EDA\.venv\lib\site-packages\IPython\core\formatters.py:406: FutureWarning: RangeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
#                 x              y   ppscore            case  is_valid_score
# 0              Id             Id  1.000000  predict_itself            True  \
# 1              Id  SepalLengthCm  0.202091      regression            True
# 2              Id   SepalWidthCm  0.000000      regression            True
# 3              Id  PetalLengthCm  0.685595      regression            True
# 4              Id   PetalWidthCm  0.643077      regression            True
# 5              Id        Species  0.979345  classification            True
# 6   SepalLengthCm             Id  0.237121      regression            True
# 7   SepalLengthCm  SepalLengthCm  1.000000  predict_itself            True
# 8   SepalLengthCm   SepalWidthCm  0.000000      regression            True
# 9   SepalLengthCm  PetalLengthCm  0.550575      regression            True
# 10  SepalLengthCm   PetalWidthCm  0.431163      regression            True
# 11  SepalLengthCm        Species  0.471649  classification            True
# 12   SepalWidthCm             Id  0.086679      regression            True
# 13   SepalWidthCm  SepalLengthCm  0.001902      regression            True
# 14   SepalWidthCm   SepalWidthCm  1.000000  predict_itself            True
# 15   SepalWidthCm  PetalLengthCm  0.167773      regression            True
# 16   SepalWidthCm   PetalWidthCm  0.129681      regression            True
# 17   SepalWidthCm        Species  0.179145  classification            True
# 18  PetalLengthCm             Id  0.554770      regression            True
# 19  PetalLengthCm  SepalLengthCm  0.524480      regression            True
# 20  PetalLengthCm   SepalWidthCm  0.041298      regression            True
# 21  PetalLengthCm  PetalLengthCm  1.000000  predict_itself            True
# 22  PetalLengthCm   PetalWidthCm  0.745236      regression            True
# 23  PetalLengthCm        Species  0.884812  classification            True
# 24   PetalWidthCm             Id  0.573713      regression            True
# 25   PetalWidthCm  SepalLengthCm  0.384320      regression            True
# 26   PetalWidthCm   SepalWidthCm  0.258780      regression            True
# 27   PetalWidthCm  PetalLengthCm  0.798971      regression            True
# 28   PetalWidthCm   PetalWidthCm  1.000000  predict_itself            True
# 29   PetalWidthCm        Species  0.927652  classification            True
# 30        Species             Id  0.665331      regression            True
# 31        Species  SepalLengthCm  0.409634      regression            True
# 32        Species   SepalWidthCm  0.183645      regression            True
# 33        Species  PetalLengthCm  0.785451      regression            True
# 34        Species   PetalWidthCm  0.755378      regression            True
# 35        Species        Species  1.000000  predict_itself            True
#
#                  metric  baseline_score  model_score                     model
# 0                  None        0.000000     1.000000                      None
# 1   mean absolute error        0.684667     0.546302   DecisionTreeRegressor()
# 2   mean absolute error        0.327333     0.345359   DecisionTreeRegressor()
# 3   mean absolute error        1.488000     0.467834   DecisionTreeRegressor()
# 4   mean absolute error        0.645333     0.230334   DecisionTreeRegressor()
# 5           weighted F1        0.353333     0.986643  DecisionTreeClassifier()
# 6   mean absolute error       37.500000    28.607972   DecisionTreeRegressor()
# 7                  None        0.000000     1.000000                      None
# 8   mean absolute error        0.327333     0.362073   DecisionTreeRegressor()
# 9   mean absolute error        1.488000     0.668745   DecisionTreeRegressor()
# 10  mean absolute error        0.645333     0.367090   DecisionTreeRegressor()
# 11          weighted F1        0.353333     0.658333  DecisionTreeClassifier()
# 12  mean absolute error       37.500000    34.249542   DecisionTreeRegressor()
# 13  mean absolute error        0.684667     0.683364   DecisionTreeRegressor()
# 14                 None        0.000000     1.000000                      None
# 15  mean absolute error        1.488000     1.238354   DecisionTreeRegressor()
# 16  mean absolute error        0.645333     0.561646   DecisionTreeRegressor()
# 17          weighted F1        0.353333     0.469180  DecisionTreeClassifier()
# 18  mean absolute error       37.500000    16.696138   DecisionTreeRegressor()
# 19  mean absolute error        0.684667     0.325573   DecisionTreeRegressor()
# 20  mean absolute error        0.327333     0.313815   DecisionTreeRegressor()
# 21                 None        0.000000     1.000000                      None
# 22  mean absolute error        0.645333     0.164408   DecisionTreeRegressor()
# 23          weighted F1        0.353333     0.925512  DecisionTreeClassifier()
# 24  mean absolute error       37.500000    15.985775   DecisionTreeRegressor()
# 25  mean absolute error        0.684667     0.421535   DecisionTreeRegressor()
# 26  mean absolute error        0.327333     0.242626   DecisionTreeRegressor()
# 27  mean absolute error        1.488000     0.299131   DecisionTreeRegressor()
# 28                 None        0.000000     1.000000                      None
# 29          weighted F1        0.353333     0.953215  DecisionTreeClassifier()
# 30  mean absolute error       37.500000    12.550092   DecisionTreeRegressor()
# 31  mean absolute error        0.684667     0.404204   DecisionTreeRegressor()
# 32  mean absolute error        0.327333     0.267220   DecisionTreeRegressor()
# 33  mean absolute error        1.488000     0.319249   DecisionTreeRegressor()
# 34  mean absolute error        0.645333     0.157863   DecisionTreeRegressor()
# 35                 None        0.000000     1.000000                      None

# %%
PPS_DATAFRAME=PPS_DATAFRAME[PPS_DATAFRAME["case"] != "predict_itself"]

# %%
PPS_DATAFRAME
# Out:
# c:\Users\Nagesh Agrawal\OneDrive\Desktop\EDA\.venv\lib\site-packages\IPython\core\formatters.py:406: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
# c:\Users\Nagesh Agrawal\OneDrive\Desktop\EDA\.venv\lib\site-packages\IPython\core\formatters.py:406: FutureWarning: RangeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
#                 x              y   ppscore            case  is_valid_score
# 0              Id             Id  1.000000  predict_itself            True  \
# 1              Id  SepalLengthCm  0.202091      regression            True
# 2              Id   SepalWidthCm  0.000000      regression            True
# 3              Id  PetalLengthCm  0.685595      regression            True
# 4              Id   PetalWidthCm  0.643077      regression            True
# 5              Id        Species  0.979345  classification            True
# 6   SepalLengthCm             Id  0.237121      regression            True
# 7   SepalLengthCm  SepalLengthCm  1.000000  predict_itself            True
# 8   SepalLengthCm   SepalWidthCm  0.000000      regression            True
# 9   SepalLengthCm  PetalLengthCm  0.550575      regression            True
# 10  SepalLengthCm   PetalWidthCm  0.431163      regression            True
# 11  SepalLengthCm        Species  0.471649  classification            True
# 12   SepalWidthCm             Id  0.086679      regression            True
# 13   SepalWidthCm  SepalLengthCm  0.001902      regression            True
# 14   SepalWidthCm   SepalWidthCm  1.000000  predict_itself            True
# 15   SepalWidthCm  PetalLengthCm  0.167773      regression            True
# 16   SepalWidthCm   PetalWidthCm  0.129681      regression            True
# 17   SepalWidthCm        Species  0.179145  classification            True
# 18  PetalLengthCm             Id  0.554770      regression            True
# 19  PetalLengthCm  SepalLengthCm  0.524480      regression            True
# 20  PetalLengthCm   SepalWidthCm  0.041298      regression            True
# 21  PetalLengthCm  PetalLengthCm  1.000000  predict_itself            True
# 22  PetalLengthCm   PetalWidthCm  0.745236      regression            True
# 23  PetalLengthCm        Species  0.884812  classification            True
# 24   PetalWidthCm             Id  0.573713      regression            True
# 25   PetalWidthCm  SepalLengthCm  0.384320      regression            True
# 26   PetalWidthCm   SepalWidthCm  0.258780      regression            True
# 27   PetalWidthCm  PetalLengthCm  0.798971      regression            True
# 28   PetalWidthCm   PetalWidthCm  1.000000  predict_itself            True
# 29   PetalWidthCm        Species  0.927652  classification            True
# 30        Species             Id  0.665331      regression            True
# 31        Species  SepalLengthCm  0.409634      regression            True
# 32        Species   SepalWidthCm  0.183645      regression            True
# 33        Species  PetalLengthCm  0.785451      regression            True
# 34        Species   PetalWidthCm  0.755378      regression            True
# 35        Species        Species  1.000000  predict_itself            True
#
#                  metric  baseline_score  model_score                     model
# 0                  None        0.000000     1.000000                      None
# 1   mean absolute error        0.684667     0.546302   DecisionTreeRegressor()
# 2   mean absolute error        0.327333     0.345359   DecisionTreeRegressor()
# 3   mean absolute error        1.488000     0.467834   DecisionTreeRegressor()
# 4   mean absolute error        0.645333     0.230334   DecisionTreeRegressor()
# 5           weighted F1        0.353333     0.986643  DecisionTreeClassifier()
# 6   mean absolute error       37.500000    28.607972   DecisionTreeRegressor()
# 7                  None        0.000000     1.000000                      None
# 8   mean absolute error        0.327333     0.362073   DecisionTreeRegressor()
# 9   mean absolute error        1.488000     0.668745   DecisionTreeRegressor()
# 10  mean absolute error        0.645333     0.367090   DecisionTreeRegressor()
# 11          weighted F1        0.353333     0.658333  DecisionTreeClassifier()
# 12  mean absolute error       37.500000    34.249542   DecisionTreeRegressor()
# 13  mean absolute error        0.684667     0.683364   DecisionTreeRegressor()
# 14                 None        0.000000     1.000000                      None
# 15  mean absolute error        1.488000     1.238354   DecisionTreeRegressor()
# 16  mean absolute error        0.645333     0.561646   DecisionTreeRegressor()
# 17          weighted F1        0.353333     0.469180  DecisionTreeClassifier()
# 18  mean absolute error       37.500000    16.696138   DecisionTreeRegressor()
# 19  mean absolute error        0.684667     0.325573   DecisionTreeRegressor()
# 20  mean absolute error        0.327333     0.313815   DecisionTreeRegressor()
# 21                 None        0.000000     1.000000                      None
# 22  mean absolute error        0.645333     0.164408   DecisionTreeRegressor()
# 23          weighted F1        0.353333     0.925512  DecisionTreeClassifier()
# 24  mean absolute error       37.500000    15.985775   DecisionTreeRegressor()
# 25  mean absolute error        0.684667     0.421535   DecisionTreeRegressor()
# 26  mean absolute error        0.327333     0.242626   DecisionTreeRegressor()
# 27  mean absolute error        1.488000     0.299131   DecisionTreeRegressor()
# 28                 None        0.000000     1.000000                      None
# 29          weighted F1        0.353333     0.953215  DecisionTreeClassifier()
# 30  mean absolute error       37.500000    12.550092   DecisionTreeRegressor()
# 31  mean absolute error        0.684667     0.404204   DecisionTreeRegressor()
# 32  mean absolute error        0.327333     0.267220   DecisionTreeRegressor()
# 33  mean absolute error        1.488000     0.319249   DecisionTreeRegressor()
# 34  mean absolute error        0.645333     0.157863   DecisionTreeRegressor()
# 35                 None        0.000000     1.000000                      None
