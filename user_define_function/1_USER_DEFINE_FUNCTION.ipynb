# %% [markdown]
# ---
#
# ````markdown
# # 🔷 Basic Programming Concepts (Short Notes)
#
#
# ## 🌟 User-Defined Function (UDF)
# **➤ A function created by the user to perform specific tasks.**
#
# ```python
# def greet(name):
#     return "Hello " + name
# ````
#
# ---
#
# ## 🔧 Instruction
#
# **➤ A single line of code that tells the computer to do something.**
#
# ```python
# x = 10  # This is an instruction
# ```
#
# ---
#
# ## 📚 Collection of All Functions
#
# **➤ Called a Function Library, Module, or Codebase**
# (Depends on how functions are grouped or organized.)
#
# ---
#
# ## 📦 Package
#
# **➤ A folder that contains Python modules.**
# **➤ Used to organize and reuse code easily.**
#
# ✅ Example Packages: `pandas`, `numpy`, `sklearn`
#
# ```python
# import pandas
# ```
#
# ---
#
# ## 🏗️ Class
#
# **➤ A blueprint to create objects (with data and behavior).**
#
# ```python
# class Car:
#     def drive(self):
#         print("Driving")
# ```
#
# ➡️ You can import a class from a package:
#
# ```python
# from sklearn.linear_model import LogisticRegression
# ```
#
# ---
