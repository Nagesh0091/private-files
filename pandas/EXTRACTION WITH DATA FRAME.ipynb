# %% [markdown]
# # **🧑‍💻EXTRACTION FROM DATAFRME**

# %%
# LOADING DATA:
import pandas as pd
DATA=pd.read_csv(r"C:\Users\Nagesh Agrawal\OneDrive\Desktop\PANDAS\z_DATA\archive (1)\2019-Nov.csv")

# %%
# SINGLE COLUMN:
DATA["brand"]
# Out:
# 0               NaN
# 1               NaN
# 2               pnb
# 3          jessnail
# 4               NaN
#              ...
# 4635832         NaN
# 4635833     beautix
# 4635834        kims
# 4635835         NaN
# 4635836      rasyan
# Name: brand, Length: 4635837, dtype: object

# %%
# MULTIPLE COLUMNS:
DATA[["brand","price"]]
# Out:
#             brand  price
# 0             NaN   0.32
# 1             NaN   2.38
# 2             pnb  22.22
# 3        jessnail   3.16
# 4             NaN   3.33
# ...           ...    ...
# 4635832       NaN   4.76
# 4635833   beautix   9.37
# 4635834      kims  31.10
# 4635835       NaN   2.86
# 4635836    rasyan   3.76
#
# [4635837 rows x 2 columns]

# %%
# SELECTING ROW BY LOC FUNCTION: BY INDEX OF ROW 
DATA.loc[0]
# Out:
# event_time                    2019-11-01 00:00:02 UTC
# event_type                                       view
# product_id                                    5802432
# category_id                       1487580009286598681
# category_code                                     NaN
# brand                                             NaN
# price                                            0.32
# user_id                                     562076640
# user_session     09fafd6c-6c99-46b1-834f-33527f4de241
# Name: 0, dtype: object

# %%
DATA.loc[0:5]
# Out:
#                 event_time        event_type  product_id          category_id  \
# 0  2019-11-01 00:00:02 UTC              view     5802432  1487580009286598681
# 1  2019-11-01 00:00:09 UTC              cart     5844397  1487580006317032337
# 2  2019-11-01 00:00:10 UTC              view     5837166  1783999064103190764
# 3  2019-11-01 00:00:11 UTC              cart     5876812  1487580010100293687
# 4  2019-11-01 00:00:24 UTC  remove_from_cart     5826182  1487580007483048900
# 5  2019-11-01 00:00:24 UTC  remove_from_cart     5826182  1487580007483048900
#
#   category_code     brand  price    user_id  \
# 0           NaN       NaN   0.32  562076640
# 1           NaN       NaN   2.38  553329724
# 2           NaN       pnb  22.22  556138645
# 3           NaN  jessnail   3.16  564506666
# 4           NaN       NaN   3.33  553329724
# 5           NaN       NaN   3.33  553329724
#
#                            user_session
# 0  09fafd6c-6c99-46b1-834f-33527f4de241
# ...

# %%
# SELECTING ROW BY ILOC FUNCTION: BY INDEX OF ROW 
DATA.iloc[0]
# Out:
# event_time                    2019-11-01 00:00:02 UTC
# event_type                                       view
# product_id                                    5802432
# category_id                       1487580009286598681
# category_code                                     NaN
# brand                                             NaN
# price                                            0.32
# user_id                                     562076640
# user_session     09fafd6c-6c99-46b1-834f-33527f4de241
# Name: 0, dtype: object

# %%
DATA.iloc[0:5] #0 to 4 only .
# Out:
#                 event_time        event_type  product_id          category_id  \
# 0  2019-11-01 00:00:02 UTC              view     5802432  1487580009286598681
# 1  2019-11-01 00:00:09 UTC              cart     5844397  1487580006317032337
# 2  2019-11-01 00:00:10 UTC              view     5837166  1783999064103190764
# 3  2019-11-01 00:00:11 UTC              cart     5876812  1487580010100293687
# 4  2019-11-01 00:00:24 UTC  remove_from_cart     5826182  1487580007483048900
#
#   category_code     brand  price    user_id  \
# 0           NaN       NaN   0.32  562076640
# 1           NaN       NaN   2.38  553329724
# 2           NaN       pnb  22.22  556138645
# 3           NaN  jessnail   3.16  564506666
# 4           NaN       NaN   3.33  553329724
#
#                            user_session
# 0  09fafd6c-6c99-46b1-834f-33527f4de241
# 1  2067216c-31b5-455d-a1cc-af0575a34ffb
# 2  57ed222e-a54a-4907-9944-5a875c2d7f4f
# 3  186c1951-8052-4b37-adce-dd9644b1d5f7
# ...

# %%
# CONDITIONAL SELECTION:
DATA[DATA["price"]>327]
# Out:
#                       event_time event_type  product_id          category_id  \
# 2809483  2019-11-21 11:22:00 UTC       view     5906221  1487580006300255120
# 2815661  2019-11-21 11:50:46 UTC       view     5906221  1487580006300255120
# 2833486  2019-11-21 13:18:42 UTC       view     5906221  1487580006300255120
# 2854007  2019-11-21 15:07:45 UTC       view     5906221  1487580006300255120
# 2854097  2019-11-21 15:08:13 UTC       cart     5906221  1487580006300255120
# ...                          ...        ...         ...                  ...
# 4009862  2019-11-27 18:43:59 UTC       view     5906221  1487580006300255120
# 4012126  2019-11-27 18:59:45 UTC       view     5906221  1487580006300255120
# 4030902  2019-11-27 21:07:37 UTC       view     5906221  1487580006300255120
# 4031759  2019-11-27 21:14:38 UTC       view     5906221  1487580006300255120
# 4040899  2019-11-27 22:51:33 UTC       view     5906221  1487580006300255120
#
# ...

# %%
# MULTIPLE COMDITIONS:
DATA[(DATA["price"]>327) & (DATA["brand"]=="strong")]
# Out:
#                       event_time event_type  product_id          category_id  \
# 2809483  2019-11-21 11:22:00 UTC       view     5906221  1487580006300255120
# 2815661  2019-11-21 11:50:46 UTC       view     5906221  1487580006300255120
# 2833486  2019-11-21 13:18:42 UTC       view     5906221  1487580006300255120
# 2854007  2019-11-21 15:07:45 UTC       view     5906221  1487580006300255120
# 2854097  2019-11-21 15:08:13 UTC       cart     5906221  1487580006300255120
# ...                          ...        ...         ...                  ...
# 4009862  2019-11-27 18:43:59 UTC       view     5906221  1487580006300255120
# 4012126  2019-11-27 18:59:45 UTC       view     5906221  1487580006300255120
# 4030902  2019-11-27 21:07:37 UTC       view     5906221  1487580006300255120
# 4031759  2019-11-27 21:14:38 UTC       view     5906221  1487580006300255120
# 4040899  2019-11-27 22:51:33 UTC       view     5906221  1487580006300255120
#
# ...

# %%
DATA.loc[:5,"brand"]
# Out:
# 0         NaN
# 1         NaN
# 2         pnb
# 3    jessnail
# 4         NaN
# 5         NaN
# Name: brand, dtype: object

# %%
DATA.columns
# Out:
# Index(['event_time', 'event_type', 'product_id', 'category_id',
#        'category_code', 'brand', 'price', 'user_id', 'user_session'],
#       dtype='object')

# %%
DATA.iloc[:5,5]
# Out:
# 0         NaN
# 1         NaN
# 2         pnb
# 3    jessnail
# 4         NaN
# Name: brand, dtype: object

# %%
# slicing:
DATA.loc[:5,["price","brand"]]
# Out:
#    price     brand
# 0   0.32       NaN
# 1   2.38       NaN
# 2  22.22       pnb
# 3   3.16  jessnail
# 4   3.33       NaN
# 5   3.33       NaN

# %%
DATA[DATA.duplicated()]
# Out:
#                       event_time        event_type  product_id  \
# 5        2019-11-01 00:00:24 UTC  remove_from_cart     5826182
# 91       2019-11-01 00:06:22 UTC  remove_from_cart     5826980
# 161      2019-11-01 00:13:16 UTC  remove_from_cart     5749153
# 163      2019-11-01 00:13:17 UTC  remove_from_cart     5749156
# 174      2019-11-01 00:13:39 UTC  remove_from_cart     5804460
# ...                          ...               ...         ...
# 4635730  2019-11-30 23:56:08 UTC  remove_from_cart     5700047
# 4635773  2019-11-30 23:57:31 UTC              cart     5670333
# 4635824  2019-11-30 23:59:24 UTC  remove_from_cart     5608703
# 4635827  2019-11-30 23:59:25 UTC  remove_from_cart     5810080
# 4635829  2019-11-30 23:59:27 UTC  remove_from_cart     5801131
#
#                  category_id category_code    brand  price    user_id  \
# 5        1487580007483048900           NaN      NaN   3.33  553329724
# ...

# %%
DATA[DATA.duplicated(keep=False)]
# Out:
#                       event_time        event_type  product_id  \
# 4        2019-11-01 00:00:24 UTC  remove_from_cart     5826182
# 5        2019-11-01 00:00:24 UTC  remove_from_cart     5826182
# 90       2019-11-01 00:06:22 UTC  remove_from_cart     5826980
# 91       2019-11-01 00:06:22 UTC  remove_from_cart     5826980
# 160      2019-11-01 00:13:16 UTC  remove_from_cart     5749153
# ...                          ...               ...         ...
# 4635824  2019-11-30 23:59:24 UTC  remove_from_cart     5608703
# 4635826  2019-11-30 23:59:25 UTC  remove_from_cart     5810080
# 4635827  2019-11-30 23:59:25 UTC  remove_from_cart     5810080
# 4635828  2019-11-30 23:59:27 UTC  remove_from_cart     5801131
# 4635829  2019-11-30 23:59:27 UTC  remove_from_cart     5801131
#
#                  category_id category_code   brand  price    user_id  \
# 4        1487580007483048900           NaN     NaN   3.33  553329724
# ...

# %%
DATA[DATA.isna()]
# Out:
#         event_time event_type  product_id  category_id category_code brand  \
# 0              NaN        NaN         NaN          NaN           NaN   NaN
# 1              NaN        NaN         NaN          NaN           NaN   NaN
# 2              NaN        NaN         NaN          NaN           NaN   NaN
# 3              NaN        NaN         NaN          NaN           NaN   NaN
# 4              NaN        NaN         NaN          NaN           NaN   NaN
# ...            ...        ...         ...          ...           ...   ...
# 4635832        NaN        NaN         NaN          NaN           NaN   NaN
# 4635833        NaN        NaN         NaN          NaN           NaN   NaN
# 4635834        NaN        NaN         NaN          NaN           NaN   NaN
# 4635835        NaN        NaN         NaN          NaN           NaN   NaN
# 4635836        NaN        NaN         NaN          NaN           NaN   NaN
#
#          price  user_id user_session
# ...

# %% [markdown]
# Awesome! Here's your **decorative version** — same content but more stylish, clean, and colorful-looking (I'll suggest symbols, boxes, and neat sections):
#
# ---
#
# # 📚 `.iloc` Selection
#
# ---
#
# ### ✨ Extracting all Rows and single column
# ```python
# df.iloc[:, 1]
# ```
#
# ---
#
# ### ✨ Extracting all Rows and range of columns only
# ```python
# df.iloc[:, 1:3]
# ```
#
# ---
#
# ### ✨ Extracting all Rows and single column
# ```python
# df.iloc[:, 1]
# ```
#
# ---
#
# ### ✨ Extracting top 5 Rows and range of columns only
# ```python
# df.iloc[0:5, 1:4]
# ```
#
# ---
#
# ### ✨ Extracting top 5 Rows and single column
# ```python
# df.iloc[0:5, 1]
# ```
#
# ---
#
# ### ✨ Extracting all columns and single Row
# ```python
# df.iloc[2, :]
# ```
# or
# ```python
# df.iloc[[2]]
# ```
#
# ---
#
# ### ✨ Extracting random records by using index parameter
# ```python
# df.iloc[[0, 2, 4]]
# ```
# or
# ```python
# df.iloc[[0, 2, 4], :]
# ```
#
# ---
#
# ### ✨ Skipped Rows (start:stop:endvalue/stepvalue)
# ```python
# df.iloc[0:10:2]
# ```
#
# ---
#
# # 📚 `.loc` Selection
#
# ---
#
# ### ✨ Accessing single value
# ```python
# df.loc['rowlabel', 'columnlabel']
# ```
#
# ---
#
# ### ✨ Accessing single Row
# ```python
# df.loc['rowlabel']
# ```
#
# ---
#
# ### ✨ Accessing multiple Rows
# ```python
# df.loc[['a', 'b']]
# ```
#
# ---
#
# ### ✨ Accessing single Column
# ```python
# df.loc[:, 'colname']
# ```
#
# ---
#
# ### ✨ Accessing multiple Columns
# ```python
# df.loc[:, ['name', 'city']]
# ```
#
# ---
#
# ### ✨ Accessing multiple Rows and Columns
# ```python
# df.loc[['rowlabel1', 'rowlabel2'], ['columnlabel1', 'columnlabel2']]
# ```
#
# ---
