# %% [markdown]
# # **😍FUNCTIONS IN 🐼 PANDAS😍**

# %%
# LOADING DATA:
import pandas as pd
DATA=pd.read_csv(r"C:\Users\Nagesh Agrawal\OneDrive\Desktop\2_PANDAS\z_DATA\archive (1)\2019-Dec.csv")

# %% [markdown]
# # **ATTRIBUTE**

# %%
# ATTRIBUTE SHAPE:
DATA.shape
# Out:
# (3533286, 9)

# %%
# ATTRIBUTE COLUMNS:
DATA.columns
# Out:
# Index(['event_time', 'event_type', 'product_id', 'category_id',
#        'category_code', 'brand', 'price', 'user_id', 'user_session'],
#       dtype='object')

# %%
# ATTRIBUTE VALUES:
DATA.values
# Out:
# array([['2019-12-01 00:00:00 UTC', 'remove_from_cart', 5712790, ...,
#         6.27, 576802932, '51d85cb0-897f-48d2-918b-ad63965c12dc'],
#        ['2019-12-01 00:00:00 UTC', 'view', 5764655, ..., 29.05,
#         412120092, '8adff31e-2051-4894-9758-224bfa8aec18'],
#        ['2019-12-01 00:00:02 UTC', 'cart', 4958, ..., 1.19, 494077766,
#         'c99a50e8-2fac-4c4d-89ec-41c05f114554'],
#        ...,
#        ['2019-12-31 23:59:51 UTC', 'view', 59975, ..., 7.14, 595414541,
#         '4c6d80bb-5dd3-4fbb-b592-187b51db2753'],
#        ['2019-12-31 23:59:52 UTC', 'view', 5775982, ..., 11.9, 397780878,
#         '7e8a2b85-153a-44eb-a71f-b748fde14fcc'],
#        ['2019-12-31 23:59:57 UTC', 'view', 5635090, ..., 4.44, 420652863,
#         '546f6af3-a517-4752-a98b-80c4c5860711']], dtype=object)

# %%
# ATTRIBUTE INDEX:
DATA.index
# Out:
# RangeIndex(start=0, stop=3533286, step=1)

# %%
# ATTRIBUTES DTYPE :
DATA.dtypes
# Out:
# event_time        object
# event_type        object
# product_id         int64
# category_id        int64
# category_code     object
# brand             object
# price            float64
# user_id            int64
# user_session      object
# dtype: object

# %%
# ATTRIBUTE SIZE:
DATA.size
# Out:
# 31799574

# %%
# ATTRIBUTE NDIM: 2DIMENSIONS DATAFRAME...
DATA.ndim
# Out:
# 2

# %%
# ATTRIBUTE T :TRANSPOSE(SWAP ROWS AND COLUMNS)
#DATA.T

# %%
dir(DATA)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %% [markdown]
# # **FUNCTIONS**

# %%
# HEAD FUNCTION:
DATA.head()
# Out:
#                 event_time        event_type  product_id          category_id  \
# 0  2019-12-01 00:00:00 UTC  remove_from_cart     5712790  1487580005268456287
# 1  2019-12-01 00:00:00 UTC              view     5764655  1487580005411062629
# 2  2019-12-01 00:00:02 UTC              cart        4958  1487580009471148064
# 3  2019-12-01 00:00:05 UTC              view     5848413  1487580007675986893
# 4  2019-12-01 00:00:07 UTC              view     5824148  1487580005511725929
#
#   category_code      brand  price    user_id  \
# 0           NaN      f.o.x   6.27  576802932
# 1           NaN        cnd  29.05  412120092
# 2           NaN     runail   1.19  494077766
# 3           NaN  freedecor   0.79  348405118
# 4           NaN        NaN   5.56  576005683
#
#                            user_session
# 0  51d85cb0-897f-48d2-918b-ad63965c12dc
# 1  8adff31e-2051-4894-9758-224bfa8aec18
# 2  c99a50e8-2fac-4c4d-89ec-41c05f114554
# 3  722ffea5-73c0-4924-8e8f-371ff8031af4
# ...

# %%
# TAIL FUNCTION:
DATA.tail()
# Out:
#                       event_time event_type  product_id          category_id  \
# 3533281  2019-12-31 23:59:39 UTC       view     5683350  1487580005671109489
# 3533282  2019-12-31 23:59:46 UTC       view     5888097  1487580013388628160
# 3533283  2019-12-31 23:59:51 UTC       view       59975  1487580012096782476
# 3533284  2019-12-31 23:59:52 UTC       view     5775982  1783999063314661546
# 3533285  2019-12-31 23:59:57 UTC       view     5635090  1487580005754995573
#
#         category_code   brand   price    user_id  \
# 3533281           NaN  masura    2.84  536812729
# 3533282           NaN    shik  179.05  503658154
# 3533283           NaN     NaN    7.14  595414541
# 3533284           NaN     NaN   11.90  397780878
# 3533285           NaN     NaN    4.44  420652863
#
#                                  user_session
# 3533281  e4a2d47c-a956-4c46-8176-745f52ea664b
# 3533282  2dde9867-9e71-4a64-880d-aa68b66aae6d
# 3533283  4c6d80bb-5dd3-4fbb-b592-187b51db2753
# ...

# %%
# INFO FUNCTION:
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3533286 entries, 0 to 3533285
# Data columns (total 9 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   event_time     object
#  1   event_type     object
#  2   product_id     int64
#  3   category_id    int64
#  4   category_code  object
#  5   brand          object
#  6   price          float64
#  7   user_id        int64
#  8   user_session   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 242.6+ MB

# %%
# astype() function: convert datatype of column....
DATA["price"]=DATA["price"].astype("float")

# %%
# DESCRIBE FUNCTION:
DATA.describe()
# Out:
#          product_id   category_id         price       user_id
# count  3.533286e+06  3.533286e+06  3.533286e+06  3.533286e+06
# mean   5.473054e+06  1.555023e+18  8.871856e+00  5.223318e+08
# std    1.331331e+06  1.689262e+17  1.986474e+01  8.494819e+07
# min    3.752000e+03  1.487580e+18 -7.937000e+01  1.180452e+06
# 25%    5.726191e+06  1.487580e+18  2.060000e+00  4.866830e+08
# 50%    5.811429e+06  1.487580e+18  4.210000e+00  5.566496e+08
# 75%    5.859462e+06  1.487580e+18  7.140000e+00  5.828019e+08
# max    5.917178e+06  2.235524e+18  3.277800e+02  5.954145e+08

# %%
# DESCRIBE OJECT FUNCTION:
DATA.describe(include="object")
# Out:
#                      event_time event_type                  category_code  \
# count                   3533286    3533286                          58465
# unique                  1654771          4                             10
# top     2019-12-02 14:12:08 UTC       view  appliances.environment.vacuum
# freq                        260    1728331                          25818
#
#           brand                          user_session
# count   2022997                               3532507
# unique      252                                839812
# top      runail  d53d1c2e-9195-6051-cf7b-7332dfeae818
# freq     256217                                  1393

# %%
# ISNULL FUNCTION: NULL VALUES FROM 3533285
DATA.isna().sum()
# Out:
# event_time             0
# event_type             0
# product_id             0
# category_id            0
# category_code    3474821
# brand            1510289
# price                  0
# user_id                0
# user_session         779
# dtype: int64

# %%
# PERCENTAGE OF NULL CALCULATION:
(DATA.isna().sum()/len(DATA))*100
# Out:
# event_time        0.000000
# event_type        0.000000
# product_id        0.000000
# category_id       0.000000
# category_code    98.345308
# brand            42.744601
# price             0.000000
# user_id           0.000000
# user_session      0.022047
# dtype: float64

# %%
# DROP FUNCTION:
# FOR category_code HAVING NULL VALUE MORE THAN 50 %
DATA.drop("category_code",axis=1,inplace=True)
(DATA.isna().sum()/len(DATA)*100)
# Out:
# event_time       0.000000
# event_type       0.000000
# product_id       0.000000
# category_id      0.000000
# brand           42.744601
# price            0.000000
# user_id          0.000000
# user_session     0.022047
# dtype: float64

# %%
# FILLNA FUNCTION: 
# user_session HAVING NULL VALUES BETWEEN 5 % AND 50%
# SO IT THOSE VALUES SHOULD BE REPLACE..
# user_session IS CATEGORICAL
DATA['brand'] = DATA['brand'].fillna('Unknown')
(DATA.isna().sum()/len(DATA)*100)
# Out:
# event_time      0.000000
# event_type      0.000000
# product_id      0.000000
# category_id     0.000000
# brand           0.000000
# price           0.000000
# user_id         0.000000
# user_session    0.022047
# dtype: float64

# %% [markdown]
# ---
#
# # `dropna()` function:
# 👉 Used to **remove missing values** (`NaN`) from a DataFrame.
#
# ---
#
# # Important `dropna()` parameters:
#
# | Parameter | Meaning (in simple words) |
# |:----------|:---------------------------|
# | `axis` | 0 = drop rows (default), 1 = drop columns |
# | `how` | `'any'` = drop if **any** NaN, `'all'` = drop if **all** values are NaN |
# | `thresh` | Keep rows/columns with **at least** this many **non-NaN** values |
# | `subset` | Only look at **specific columns** when checking for NaN |
# | `inplace` | `True` = update the same DataFrame, `False` = create a new one |
#
# ---

# %%
# DROPNA FUNCTION:
DATA.dropna(axis=0,inplace=True)
(DATA.isna().sum()/len(DATA)*100)
# Out:
# event_time      0.0
# event_type      0.0
# product_id      0.0
# category_id     0.0
# brand           0.0
# price           0.0
# user_id         0.0
# user_session    0.0
# dtype: float64

# %%
DATA.shape
# Out:
# (3532507, 8)

# %%
# FILLNA FUNCTION:
DATA.fillna(0,inplace=True)
(DATA.isna().sum()/len(DATA)*100)
# Out:
# event_time      0.0
# event_type      0.0
# product_id      0.0
# category_id     0.0
# brand           0.0
# price           0.0
# user_id         0.0
# user_session    0.0
# dtype: float64

# %%
# RENAME FUNCTION:
DATA.rename(columns={"event_time":"EVENT_TIME",
                     "event_type":"EVENT_TYPE",
                     "product_id":"PRODUCT_ID",
                     "category_id":"CATEGORY_ID",
                     "brand":"BRAND",
                     "price":"PRICE",
                     "user_id":"USER_ID",
                     "user_session":"USER_SESSION"},inplace=True)
DATA.columns
# Out:
# Index(['EVENT_TIME', 'EVENT_TYPE', 'PRODUCT_ID', 'CATEGORY_ID', 'BRAND',
#        'PRICE', 'USER_ID', 'USER_SESSION'],
#       dtype='object')

# %%
# duplicated() function and drop_duplicates() function.
print(DATA.duplicated().sum())
DATA.drop_duplicates(inplace=True)
print(DATA.duplicated().sum())
# Out:
# 183795
# 0

# %%
DATA.value_counts()
# Out:
# EVENT_TIME               EVENT_TYPE        PRODUCT_ID  CATEGORY_ID          BRAND       PRICE  USER_ID    USER_SESSION
# 2019-12-01 00:00:00 UTC  remove_from_cart  5712790     1487580005268456287  f.o.x       6.27   576802932  51d85cb0-897f-48d2-918b-ad63965c12dc    1
# 2019-12-19 00:32:33 UTC  view              5809910     1602943681873052386  grattol     5.24   516019076  1a1e50da-9a21-4e37-8842-d176255feaaa    1
# 2019-12-19 00:31:59 UTC  view              5819232     1487580005713052531  ingarden    4.44   560264278  60846d6e-882a-4325-b186-c699a179287f    1
# 2019-12-19 00:32:02 UTC  cart              5859418     1487580005671109489  masura      2.37   561856413  297909aa-7cf3-4445-b0da-9e0dca0fc258    1
# 2019-12-19 00:32:05 UTC  view              5813103     1842735760499802745  kinetics    9.44   535333270  71336d82-bc34-4b2a-9a30-d529bb5ae38f    1
# ...

# %%
DATA['BRAND'].unique()
# Out:
# array(['f.o.x', 'cnd', 'runail', 'freedecor', 'Unknown', 'ingarden',
#        'roubloff', 'metzger', 'staleks', 'zinger', 'yoko', 'entity',
#        'irisk', 'beautix', 'uno', 'philips', 'domix', 'masura', 'grattol',
#        'strong', 'skinlite', 'nagaraku', 'italwax', 'max', 'bluesky',
#        'pole', 'cosmoprofi', 'severina', 'bpw.style', 'igrobeauty',
#        'smart', 'coifin', 'estel', 'lador', 'kapous', 'sophin',
#        'marathon', 'nitrimax', 'jessnail', 'jas', 'de.lux', 'haruyama',
#        'orly', 'lianail', 'almea', 'milv', 'lakme', 'concept', 'pnb',
#        'bodyton', 'rosi', 'petitfee', 'polarus', 'lovely', 'oniq',
#        'provoc', 'solomeya', 'shik', 'bioaqua', 'art-visage',
#        'refectocil', 'freshbubble', 'elskin', 'swarovski', 'airnails',
#        'kosmekka', 'bergamo', 'keen', 'gehwol', 'kinetics', 'estelare',
#        'missha', 'candy', 'naomi', 'thuya', 'balbcare', 'uskusi',
#        'farmavita', 'insight', 'ardell', 'limoni', 'happyfons',
# ...

# %%
# nunique function:
DATA.nunique()
# Out:
# EVENT_TIME          1654606
# EVENT_TYPE                4
# PRODUCT_ID            44620
# CATEGORY_ID             482
# BRAND                   253
# PRICE                  2122
# USER_ID              370108
# USER_SESSION         839812
# PRICEBY2               2122
# index_col           3348712
# EVENT_OF_PRODUCT     140828
# DIFF                    192
# dtype: int64

# %%
# SORT_VALUES FUNCTION:
DATA.sort_values(by="PRICE",ascending=False,inplace=True)# ASCENDING = FALSE/TRUE
DATA
# Out:
#                       EVENT_TIME EVENT_TYPE  PRODUCT_ID          CATEGORY_ID  \
# 1280901  2019-12-10 17:39:12 UTC       view     5906221  1487580006300255120
# 340443   2019-12-03 14:35:40 UTC       view     5906221  1487580006300255120
# 924424   2019-12-08 09:56:06 UTC       view     5906221  1487580006300255120
# 885256   2019-12-07 21:07:37 UTC       view     5906221  1487580006300255120
# 966246   2019-12-08 16:14:16 UTC       view     5906221  1487580006300255120
# ...                          ...        ...         ...                  ...
# 2548146  2019-12-20 17:56:16 UTC   purchase     5716859  1487580014042939619
# 2754627  2019-12-22 19:31:01 UTC   purchase     5716859  1487580014042939619
# 1633142  2019-12-13 08:44:49 UTC   purchase     5716859  1487580014042939619
# 3053899  2019-12-25 13:01:21 UTC   purchase     5716861  1487580014042939619
# 3403149  2019-12-29 14:30:17 UTC   purchase     5716861  1487580014042939619
#
# ...

# %%
# SELECT_DTYPE FUNCTION: TO SELECT DATA FROM PERTICULAR DATA TYPE
DATA.select_dtypes(include=["number"])# include= ["number","int","float","object","datetime","category"]
# Out:
#          PRODUCT_ID          CATEGORY_ID   PRICE    USER_ID
# 1280901     5906221  1487580006300255120  327.78  564322877
# 340443      5906221  1487580006300255120  327.78  496211390
# 924424      5906221  1487580006300255120  327.78  465789144
# 885256      5906221  1487580006300255120  327.78  583540159
# 966246      5906221  1487580006300255120  327.78  550178878
# ...             ...                  ...     ...        ...
# 2548146     5716859  1487580014042939619  -47.62  589538798
# 2754627     5716859  1487580014042939619  -47.62  590958276
# 1633142     5716859  1487580014042939619  -47.62  414087247
# 3053899     5716861  1487580014042939619  -79.37  489184067
# 3403149     5716861  1487580014042939619  -79.37  489118334
#
# [3348712 rows x 4 columns]

# %%
# GROUPBY FUNCTION:
DATA.groupby("BRAND")["PRICE"].sum()
# Out:
# BRAND
# Unknown     10897627.44
# airnails      215807.74
# almea          22006.96
# andrea           498.60
# ardell         31510.77
#                ...
# ypsed           9263.48
# yu-r           22555.37
# zab              340.04
# zeitun         23741.53
# zinger        110996.40
# Name: PRICE, Length: 253, dtype: float64

# %% [markdown]
# # **🤖ILOC AND LOC FUNCTION😊**

# %% [markdown]
# Of course! Let’s explain **`iloc`** and **`loc`** in **detail but easy language** 🤖😊
#
# ---
#
# # **🔵 1. `iloc` (Index Location)**
#
# - **`iloc`** is used to select **rows and columns by number** — that is, **by their position**.
# - Think of it like: "I want the **2nd row** and **3rd column**."
#
# ### **Key points:**
# | Feature | Detail |
# |:--------|:-------|
# | **Used with** | **Row numbers** and **column numbers** (starting from 0) |
# | **Type of indexing** | **Integer-based** |
# | **Syntax** | `df.iloc[row_position, column_position]` |
#
# ---
# ### **Examples:**
# |    | Name | Age | City      |
# |----|------|-----|-----------|
# | 0  | John | 25  | New York  |
# | 1  | Sara | 30  | Paris     |
# | 2  | Mike | 28  | London    |
#
# ---
#
# 👉 **Select 1st row:**
# ```python
# df.iloc[0]
# ```
# Gives: `John, 25, New York`
#
# 👉 **Select 2nd row, 3rd column (City of Sara):**
# ```python
# df.iloc[1, 2]
# ```
# Gives: `'Paris'`
#
# 👉 **Select first two rows:**
# ```python
# df.iloc[0:2]
# ```
# Gives: rows for John and Sara.
#
# ---
#
# # **🔴 2. `loc` (Label Location)**
#
# - **`loc`** is used to select **rows and columns by name** — not position.
# - Think of it like: "I want the **row with index 2** and the **column 'City'**."
#
# ### **Key points:**
# | Feature | Detail |
# |:--------|:-------|
# | **Used with** | **Row labels** and **column names** |
# | **Type of indexing** | **Label-based** |
# | **Syntax** | `df.loc[row_label, column_label]` |
#
# ---
#
# ### **Examples:**
# Using the same DataFrame:
#
# |    | Name | Age | City      |
# |----|------|-----|-----------|
# | 0  | John | 25  | New York  |
# | 1  | Sara | 30  | Paris     |
# | 2  | Mike | 28  | London    |
#
# ---
#
# 👉 **Select row with index 1 (Sara's data):**
# ```python
# df.loc[1]
# ```
# Gives: `Sara, 30, Paris`
#
# 👉 **Select index 2, 'City' column (Mike's City):**
# ```python
# df.loc[2, 'City']
# ```
# Gives: `'London'`
#
# 👉 **Select 'Name' and 'City' columns for index 0 and 1:**
# ```python
# df.loc[0:1, ['Name', 'City']]
# ```
# Gives:
#
# |    | Name | City     |
# |----|------|----------|
# | 0  | John | New York |
# | 1  | Sara | Paris    |
#
# ---

# %% [markdown]
# Got it! 🤖 You want **ALL** use cases for **`iloc`** and **`loc`** — explained properly and **completely**!
# I’ll cover everything neatly. 😊
#
# ---
#
# # 🚀 **`iloc` Full Use Cases** (position based)
#
# | Use Case | Code Example | Output/Meaning |
# |:---------|:-------------|:---------------|
# | Select single row | `df.iloc[2]` | Row at position 2 |
# | Select single element | `df.iloc[2, 1]` | Element at (row 2, column 1) |
# | Select multiple rows | `df.iloc[[0, 2]]` | Row 0 and 2 |
# | Select row range | `df.iloc[0:3]` | Row 0,1,2 (excludes 3) |
# | Select specific columns | `df.iloc[:, [0,2]]` | All rows, columns 0 and 2 |
# | Select column range | `df.iloc[:, 0:2]` | All rows, columns 0 and 1 |
# | Select rows and columns | `df.iloc[0:2, 1:3]` | Rows 0-1 and columns 1-2 |
# | Select last row | `df.iloc[-1]` | Last row |
# | Select last n rows | `df.iloc[-3:]` | Last 3 rows |
#
# ---
#
# # 🚀 **`loc` Full Use Cases** (label based)
#
# | Use Case | Code Example | Output/Meaning |
# |:---------|:-------------|:---------------|
# | Select single row | `df.loc[2]` | Row with label 2 |
# | Select single element | `df.loc[2, 'City']` | Value in row 2 and 'City' |
# | Select multiple rows | `df.loc[[0,2]]` | Rows 0 and 2 |
# | Select row range | `df.loc[0:2]` | Row 0,1,2 (**inclusive**) |
# | Select specific columns | `df.loc[:, ['Name', 'City']]` | All rows, only 'Name' and 'City' |
# | Select column range | `df.loc[:, 'Name':'City']` | All rows, columns between 'Name' and 'City' |
# | Select rows and columns | `df.loc[0:1, ['Name', 'City']]` | Rows 0-1, 'Name' and 'City' columns |
# | Boolean indexing (row condition) | `df.loc[df['Age'] > 25]` | Rows where Age > 25 |
# | Conditional with specific columns | `df.loc[df['Age']>25, 'City']` | 'City' of people whose Age>25 |
# | Select using labels | `df.loc[0:2, 'Age']` | 'Age' column for rows 0 to 2 |
#
# ---
#
# # 🧠 **More Special Tricks**
#
# | Special Case | `iloc` Example | `loc` Example |
# |:-------------|:---------------|:--------------|
# | Select every alternate row | `df.iloc[::2]` | Only by number, loc doesn't directly support |
# | Reverse DataFrame | `df.iloc[::-1]` | Same: `df.loc[::-1]` |
# | Use `.at` for fast single value | ❌ (not for `iloc`) | `df.at[2, 'City']` |
# | Use `.iat` for fast single value | `df.iat[2, 1]` | ❌ (not for `loc`) |
#
# ---
#
# # 🔥 **Difference in Range:**
# | Thing | `iloc` | `loc` |
# |:------|:------|:------|
# | Range behavior | Excludes end (like Python slices) | Includes end (special for loc) |
# | Example | `df.iloc[0:2]` → 0 and 1 only | `df.loc[0:2]` → 0, 1, and 2 |
#
# ---

# %%
# APPLY FUNCTION:applies a function to a column and rows.
DATA["PRICEBY2"]=DATA["PRICE"].apply(lambda x:x*2)
DATA
# Out:
#                       EVENT_TIME EVENT_TYPE  PRODUCT_ID          CATEGORY_ID  \
# 1280901  2019-12-10 17:39:12 UTC       view     5906221  1487580006300255120
# 340443   2019-12-03 14:35:40 UTC       view     5906221  1487580006300255120
# 924424   2019-12-08 09:56:06 UTC       view     5906221  1487580006300255120
# 885256   2019-12-07 21:07:37 UTC       view     5906221  1487580006300255120
# 966246   2019-12-08 16:14:16 UTC       view     5906221  1487580006300255120
# ...                          ...        ...         ...                  ...
# 2548146  2019-12-20 17:56:16 UTC   purchase     5716859  1487580014042939619
# 2754627  2019-12-22 19:31:01 UTC   purchase     5716859  1487580014042939619
# 1633142  2019-12-13 08:44:49 UTC   purchase     5716859  1487580014042939619
# 3053899  2019-12-25 13:01:21 UTC   purchase     5716861  1487580014042939619
# 3403149  2019-12-29 14:30:17 UTC   purchase     5716861  1487580014042939619
#
# ...

# %%
# corr() function: calculates correlation.
DATA.select_dtypes(include=["number"]).corr()
# Out:
#              PRODUCT_ID  CATEGORY_ID     PRICE   USER_ID  PRICEBY2
# PRODUCT_ID     1.000000     0.004477 -0.011251 -0.019186 -0.011251
# CATEGORY_ID    0.004477     1.000000 -0.012002 -0.002160 -0.012002
# PRICE         -0.011251    -0.012002  1.000000  0.038046  1.000000
# USER_ID       -0.019186    -0.002160  0.038046  1.000000  0.038046
# PRICEBY2      -0.011251    -0.012002  1.000000  0.038046  1.000000

# %%
# FILTER ROWS BASED ON CONDITION....
DATA[DATA["PRICE"]==0.0]
# Out:
#                       EVENT_TIME EVENT_TYPE  PRODUCT_ID          CATEGORY_ID  \
# 197982   2019-12-02 14:09:13 UTC       view     5904329  1487580007675986893
# 561225   2019-12-05 08:11:29 UTC       view     5911123  1487580008112194531
# 2363376  2019-12-19 04:14:27 UTC       view     5910266  1487580011652186237
# 837189   2019-12-07 13:45:15 UTC       view     5903992  1487580007675986893
# 2296302  2019-12-18 13:49:55 UTC       view     5914803  1487580012096782476
# ...                          ...        ...         ...                  ...
# 737580   2019-12-06 15:22:22 UTC       cart     5911730  1487580005754995573
# 2171369  2019-12-17 14:32:04 UTC       view     5914522  1487580012096782476
# 737480   2019-12-06 15:21:11 UTC       view     5911873  1487580008246412266
# 2421170  2019-12-19 13:56:43 UTC       view     5915043  1487580011652186237
# 128808   2019-12-02 01:17:31 UTC       view     5908751  1487580007399162817
#
# ...

# %%
DATA
# Out:
#                       EVENT_TIME EVENT_TYPE  PRODUCT_ID          CATEGORY_ID  \
# 1280901  2019-12-10 17:39:12 UTC       view     5906221  1487580006300255120
# 340443   2019-12-03 14:35:40 UTC       view     5906221  1487580006300255120
# 924424   2019-12-08 09:56:06 UTC       view     5906221  1487580006300255120
# 885256   2019-12-07 21:07:37 UTC       view     5906221  1487580006300255120
# 966246   2019-12-08 16:14:16 UTC       view     5906221  1487580006300255120
# ...                          ...        ...         ...                  ...
# 2548146  2019-12-20 17:56:16 UTC   purchase     5716859  1487580014042939619
# 2754627  2019-12-22 19:31:01 UTC   purchase     5716859  1487580014042939619
# 1633142  2019-12-13 08:44:49 UTC   purchase     5716859  1487580014042939619
# 3053899  2019-12-25 13:01:21 UTC   purchase     5716861  1487580014042939619
# 3403149  2019-12-29 14:30:17 UTC   purchase     5716861  1487580014042939619
#
# ...

# %%
DATA.columns
# Out:
# Index(['EVENT_TIME', 'EVENT_TYPE', 'PRODUCT_ID', 'CATEGORY_ID', 'BRAND',
#        'PRICE', 'USER_ID', 'USER_SESSION', 'PRICEBY2'],
#       dtype='object')

# %%
# QUERY() FUNCTION:
FILTERED_DATA = DATA.query('EVENT_TYPE == "remove_from_cart" and PRICE > 20')
FILTERED_DATA
# Out:
#                       EVENT_TIME        EVENT_TYPE  PRODUCT_ID  \
# 1573090  2019-12-12 18:26:37 UTC  remove_from_cart     5906221
# 2053172  2019-12-16 16:58:37 UTC  remove_from_cart     5906221
# 1717242  2019-12-13 21:23:15 UTC  remove_from_cart     5906221
# 652610   2019-12-05 20:43:37 UTC  remove_from_cart     5906221
# 652613   2019-12-05 20:43:38 UTC  remove_from_cart     5906221
# ...                          ...               ...         ...
# 241159   2019-12-02 19:47:59 UTC  remove_from_cart     5899433
# 2847893  2019-12-23 15:59:54 UTC  remove_from_cart     5899433
# 443929   2019-12-04 10:31:15 UTC  remove_from_cart     5899433
# 2661854  2019-12-21 21:15:11 UTC  remove_from_cart     5899433
# 646031   2019-12-05 19:43:46 UTC  remove_from_cart     5899433
#
#                  CATEGORY_ID    BRAND   PRICE    USER_ID  \
# 1573090  1487580006300255120   strong  327.78  525821970
# 2053172  1487580006300255120   strong  327.78  587399613
# ...

# %%
FILTERED_DATA2=DATA[(DATA["EVENT_TYPE"]=="remove_from_cart") & (DATA["PRICE"]>20)]
FILTERED_DATA2
# Out:
#                       EVENT_TIME        EVENT_TYPE  PRODUCT_ID  \
# 1573090  2019-12-12 18:26:37 UTC  remove_from_cart     5906221
# 2053172  2019-12-16 16:58:37 UTC  remove_from_cart     5906221
# 1717242  2019-12-13 21:23:15 UTC  remove_from_cart     5906221
# 652610   2019-12-05 20:43:37 UTC  remove_from_cart     5906221
# 652613   2019-12-05 20:43:38 UTC  remove_from_cart     5906221
# ...                          ...               ...         ...
# 241159   2019-12-02 19:47:59 UTC  remove_from_cart     5899433
# 2847893  2019-12-23 15:59:54 UTC  remove_from_cart     5899433
# 443929   2019-12-04 10:31:15 UTC  remove_from_cart     5899433
# 2661854  2019-12-21 21:15:11 UTC  remove_from_cart     5899433
# 646031   2019-12-05 19:43:46 UTC  remove_from_cart     5899433
#
#                  CATEGORY_ID    BRAND   PRICE    USER_ID  \
# 1573090  1487580006300255120   strong  327.78  525821970
# 2053172  1487580006300255120   strong  327.78  587399613
# ...

# %%
# creating index column:
DATA["index_col"] = range(len(DATA))

# %%
# RESET_INDEX() FUNCTION: reset index of dataframe
DATA.reset_index(drop=True,inplace=True)

# %%
# SET_INDEX() FUNCTION: TO SET PERTICULAR COLUMN AS INDEX..
DATA.set_index("EVENT_TIME")# inplace=True for permenent changes.
# Out:
#                         EVENT_TYPE  PRODUCT_ID          CATEGORY_ID    BRAND  \
# EVENT_TIME
# 2019-12-10 17:39:12 UTC       view     5906221  1487580006300255120   strong
# 2019-12-03 14:35:40 UTC       view     5906221  1487580006300255120   strong
# 2019-12-08 09:56:06 UTC       view     5906221  1487580006300255120   strong
# 2019-12-07 21:07:37 UTC       view     5906221  1487580006300255120   strong
# 2019-12-08 16:14:16 UTC       view     5906221  1487580006300255120   strong
# ...                            ...         ...                  ...      ...
# 2019-12-20 17:56:16 UTC   purchase     5716859  1487580014042939619  Unknown
# 2019-12-22 19:31:01 UTC   purchase     5716859  1487580014042939619  Unknown
# 2019-12-13 08:44:49 UTC   purchase     5716859  1487580014042939619  Unknown
# 2019-12-25 13:01:21 UTC   purchase     5716861  1487580014042939619  Unknown
# 2019-12-29 14:30:17 UTC   purchase     5716861  1487580014042939619  Unknown
#
# ...

# %%
# applymap() function :applies function to each element of dataframe...
DATA.applymap(lambda x:x*1)# multiply each element by 1
# Out:
# C:\Users\Nagesh Agrawal\AppData\Local\Temp\ipykernel_14940\2812412658.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   DATA.applymap(lambda x:x*1)# multiply each element by 1
#                       EVENT_TIME EVENT_TYPE  PRODUCT_ID          CATEGORY_ID  \
# 0        2019-12-10 17:39:12 UTC       view     5906221  1487580006300255120
# 1        2019-12-03 14:35:40 UTC       view     5906221  1487580006300255120
# 2        2019-12-08 09:56:06 UTC       view     5906221  1487580006300255120
# 3        2019-12-07 21:07:37 UTC       view     5906221  1487580006300255120
# 4        2019-12-08 16:14:16 UTC       view     5906221  1487580006300255120
# ...                          ...        ...         ...                  ...
# 3348707  2019-12-20 17:56:16 UTC   purchase     5716859  1487580014042939619
# 3348708  2019-12-22 19:31:01 UTC   purchase     5716859  1487580014042939619
# ...

# %%
# eval() function:
# DATA["EVENT_OF_PRODUCT"]=DATA.eval("EVENT_TYPE + PRODUCT_ID") --> IT WILL NOT WORK BECUASE DATATYPE MISMATCH...
DATA["EVENT_OF_PRODUCT"] = DATA["EVENT_TYPE"] + DATA["PRODUCT_ID"].astype(str)

# %%
# crosstab(): 
pd.crosstab(DATA["EVENT_TYPE"],DATA["BRAND"])
# Out:
# BRAND             Unknown  airnails  almea  andrea  ardell  art-visage  artex  \
# EVENT_TYPE
# cart               397283      4674    109       6     757        3254    953
# purchase            91655      1378     31       1     158         733    242
# remove_from_cart   220013      2310     59       4     324        1338    537
# view               719003      5330    602      79    3614        4817   2236
#
# BRAND             aura  australis  avene  ...  voesh  vosev  weaver  yllozure  \
# EVENT_TYPE                                ...
# cart                47          0     47  ...      0     77       3       256
# purchase            12          0      6  ...      0      9       0        18
# remove_from_cart    20          2     21  ...      0     17       3       117
# view               138         37    142  ...      3    837      32       421
#
# BRAND             yoko  ypsed  yu-r  zab  zeitun  zinger
# EVENT_TYPE
# ...

# %% [markdown]
# # **AGGREGATION FUNCTIONS ON DATAFRAME**

# %%
# SUM():SUMMATION:
DATA["PRICE"].sum()
# Out:
# 30411761.91999996

# %%
# min() : MINIMUM:
DATA["PRICE"].min()
# Out:
# -79.37

# %%
# idxmin(): INDEX OF  MINIMUM VALUE
DATA["PRICE"].idxmin()
# Out:
# 3348710

# %%
# max() : MAXIMUM:
DATA["PRICE"].max()
# Out:
# 327.78

# %%
# idxmax(): index of maximum value:
DATA["PRICE"].idxmax()
# Out:
# 0

# %%
# nsmallest() and nlargest(): SELECT THE SMALLEST AND LARGEST ROW BASED ON COLUMN...
DATA.nsmallest(3,"PRICE")# LEAST 3
# Out:
#                       EVENT_TIME EVENT_TYPE  PRODUCT_ID          CATEGORY_ID  \
# 3348710  2019-12-25 13:01:21 UTC   purchase     5716861  1487580014042939619
# 3348711  2019-12-29 14:30:17 UTC   purchase     5716861  1487580014042939619
# 3348706  2019-12-28 07:32:52 UTC   purchase     5716859  1487580014042939619
#
#            BRAND  PRICE    USER_ID                          USER_SESSION  \
# 3348710  Unknown -79.37  489184067  af1b35db-1024-495e-8c42-b959491ba136
# 3348711  Unknown -79.37  489118334  da505a6f-d98d-4284-84ba-cc1873f5f8ad
# 3348706  Unknown -47.62  545859098  013568f6-b7de-4f28-b4e3-e3206527c700
#
#          PRICEBY2  index_col EVENT_OF_PRODUCT
# 3348710   -158.74    3348710  purchase5716861
# 3348711   -158.74    3348711  purchase5716861
# 3348706    -95.24    3348706  purchase5716859

# %%
DATA.nlargest(3,"PRICE")# TOP 3
# Out:
#                 EVENT_TIME EVENT_TYPE  PRODUCT_ID          CATEGORY_ID  \
# 0  2019-12-10 17:39:12 UTC       view     5906221  1487580006300255120
# 1  2019-12-03 14:35:40 UTC       view     5906221  1487580006300255120
# 2  2019-12-08 09:56:06 UTC       view     5906221  1487580006300255120
#
#     BRAND   PRICE    USER_ID                          USER_SESSION  PRICEBY2  \
# 0  strong  327.78  564322877  37c65e2b-234c-45eb-b422-670686abcf3d    655.56
# 1  strong  327.78  496211390  05cb4da5-d560-4104-b98a-1bd216d7b9d1    655.56
# 2  strong  327.78  465789144  9a500ed7-071f-411d-af53-91b8552adacb    655.56
#
#    index_col EVENT_OF_PRODUCT
# 0          0      view5906221
# 1          1      view5906221
# 2          2      view5906221

# %%
# mean(): avearge
DATA["PRICE"].mean()
# Out:
# 9.081629569816682

# %%
# median(): 
DATA["PRICE"].median()
# Out:
# 4.27

# %%
# mode():
DATA["PRICE"].mode()
# Out:
# 0    5.24
# Name: PRICE, dtype: float64

# %%
# std() :standard deviation
DATA["PRICE"].std()
# Out:
# 20.25077108197239

# %%
# var() : variance
DATA["PRICE"].var()
# Out:
# 410.0937294144492

# %%
# cov(): covarience matrix..
DATA.select_dtypes("number").cov()
# Out:
#                PRODUCT_ID   CATEGORY_ID         PRICE       USER_ID  \
# PRODUCT_ID   1.786119e+12  1.011666e+21 -3.045009e+05 -2.186646e+12
# CATEGORY_ID  1.011666e+21  2.858859e+34 -4.109415e+16 -3.114200e+22
# PRICE       -3.045009e+05 -4.109415e+16  4.100937e+02  6.570469e+07
# USER_ID     -2.186646e+12 -3.114200e+22  6.570469e+07  7.272742e+15
# PRICEBY2    -6.090019e+05 -8.218829e+16  8.201875e+02  1.314094e+08
# index_col   -3.404493e+10 -9.481079e+21 -9.689967e+06 -2.369967e+12
#
#                  PRICEBY2     index_col
# PRODUCT_ID  -6.090019e+05 -3.404493e+10
# CATEGORY_ID -8.218829e+16 -9.481079e+21
# PRICE        8.201875e+02 -9.689967e+06
# USER_ID      1.314094e+08 -2.369967e+12
# PRICEBY2     1.640375e+03 -1.937993e+07
# index_col   -1.937993e+07  9.344896e+11

# %%
# skew(): SKEWNESS
DATA["PRICE"].skew()
# Out:
# 7.023318799383143

# %%
# kurt():kurtosis
DATA["PRICE"].kurt()
# Out:
# 66.7817020607933

# %%
# quantile(): find the quantile value...
print(DATA["PRICE"].quantile(0.25))
print(DATA["PRICE"].quantile(0.50))
print(DATA["PRICE"].quantile(0.75))
# Out:
# 2.06
# 4.27
# 7.14

# %%
# pct_change():PERCENTAGE CHANGE BETWEEN CONSECUTIVE ELEMENT...
DATA["PRICE"].pct_change()
# Out:
# 0               NaN
# 1          0.000000
# 2          0.000000
# 3          0.000000
# 4          0.000000
#              ...
# 3348707    0.000000
# 3348708    0.000000
# 3348709    0.000000
# 3348710    0.666737
# 3348711    0.000000
# Name: PRICE, Length: 3348712, dtype: float64

# %%
# cumsum():cumulative sum
DATA.select_dtypes("number").cumsum()
# Out:
#              PRODUCT_ID          CATEGORY_ID         PRICE           USER_ID  \
# 0               5906221  1487580006300255120  3.277800e+02         564322877
# 1              11812442  2975160012600510240  6.555600e+02        1060534267
# 2              17718663  4462740018900765360  9.833400e+02        1526323411
# 3              23624884  5950320025201020480  1.311120e+03        2109863570
# 4              29531105  7437900031501275600  1.638900e+03        2660042448
# ...                 ...                  ...           ...               ...
# 3348707  18319033486051  -584034444967661791  3.041202e+07  1750797423517044
# 3348708  18319039202910   903545569075277828  3.041197e+07  1750798014475320
# 3348709  18319044919769  2391125583118217447  3.041192e+07  1750798428562567
# 3348710  18319050636630  3878705597161157066  3.041184e+07  1750798917746634
# 3348711  18319056353491  5366285611204096685  3.041176e+07  1750799406864968
#
#              PRICEBY2      index_col
# ...

# %%
# cumproduct():cumulative product 
DATA.select_dtypes("number").cumprod()
# Out:
# c:\Users\Nagesh Agrawal\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:59: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# c:\Users\Nagesh Agrawal\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:59: RuntimeWarning: invalid value encountered in accumulate
#   return bound(*args, **kwds)
#                   PRODUCT_ID          CATEGORY_ID         PRICE  \
# 0                    5906221  1487580006300255120  3.277800e+02
# 1             34883446500841  4700479024744149248  1.074397e+05
# 2        3115159464838564085  -261776437013999616  3.521659e+07
# 3         816972234607771153  5975054328071782400  1.154330e+10
# 4       -6959367304926464003 -8401269041858084864  3.783661e+12
# ...                      ...                  ...           ...
# 3348707                    0                    0           NaN
# 3348708                    0                    0           NaN
# ...

# %%
# diff(): calculates the difference between consecutive rows ...
DATA["DIFF"]=DATA["PRICE"].diff()
DATA
# Out:
#                       EVENT_TIME EVENT_TYPE  PRODUCT_ID          CATEGORY_ID  \
# 0        2019-12-10 17:39:12 UTC       view     5906221  1487580006300255120
# 1        2019-12-03 14:35:40 UTC       view     5906221  1487580006300255120
# 2        2019-12-08 09:56:06 UTC       view     5906221  1487580006300255120
# 3        2019-12-07 21:07:37 UTC       view     5906221  1487580006300255120
# 4        2019-12-08 16:14:16 UTC       view     5906221  1487580006300255120
# ...                          ...        ...         ...                  ...
# 3348707  2019-12-20 17:56:16 UTC   purchase     5716859  1487580014042939619
# 3348708  2019-12-22 19:31:01 UTC   purchase     5716859  1487580014042939619
# 3348709  2019-12-13 08:44:49 UTC   purchase     5716859  1487580014042939619
# 3348710  2019-12-25 13:01:21 UTC   purchase     5716861  1487580014042939619
# 3348711  2019-12-29 14:30:17 UTC   purchase     5716861  1487580014042939619
#
# ...

# %% [markdown]
# # **CHANGING TABLE STRUCTURE**

# %%
# T  ATTRIBUTE: USE TO TRANSPOSE ROWS AND COLUMNS
DATA[:100].T
# Out:
#                                                     0   \
# EVENT_TIME                     2019-12-10 17:39:12 UTC
# EVENT_TYPE                                        view
# PRODUCT_ID                                     5906221
# CATEGORY_ID                        1487580006300255120
# BRAND                                           strong
# PRICE                                           327.78
# USER_ID                                      564322877
# USER_SESSION      37c65e2b-234c-45eb-b422-670686abcf3d
# PRICEBY2                                        655.56
# index_col                                            0
# EVENT_OF_PRODUCT                           view5906221
# DIFF                                               NaN
#
#                                                     1   \
# EVENT_TIME                     2019-12-03 14:35:40 UTC
# EVENT_TYPE                                        view
# PRODUCT_ID                                     5906221
# ...

# %%
# PIVOT_TABLE() :
PIVOT=DATA.pivot_table(values="PRICE",index="BRAND")
PIVOT
# Out:
#               PRICE
# BRAND
# Unknown    7.631638
# airnails  15.761594
# almea     27.474357
# andrea     5.540000
# ardell     6.493050
# ...             ...
# ypsed     23.216742
# yu-r      34.226662
# zab       17.002000
# zeitun    13.428467
# zinger     6.108773
#
# [253 rows x 1 columns]

# %%
DATA.columns
# Out:
# Index(['EVENT_TIME', 'EVENT_TYPE', 'PRODUCT_ID', 'CATEGORY_ID', 'BRAND',
#        'PRICE', 'USER_ID', 'USER_SESSION', 'PRICEBY2', 'index_col',
#        'EVENT_OF_PRODUCT', 'DIFF'],
#       dtype='object')

# %%
# creating index column:
DATA["index_col"] = range(len(DATA))

# %%
# PIVOT(): RESHAPE THE DATA WITH UNIQUE VALUES AS COLUMNS:
PIVOT2 = DATA.pivot(index="index_col", columns="BRAND", values="PRICE")

# %%
#PIVOT2

# %%
# Sample data with only DATE column
data = {
    'DATE': ['2024-05-01', '2024-05-02', '2024-05-03', '2024-05-04', '2024-05-05']
}

# Create DataFrame
import pandas as pd
df = pd.DataFrame(data)


# 1️⃣ String to datetime (with time)
df['DATE'] = pd.to_datetime(df['DATE'])
# ➤ Jab string format mein date ho: "2024-05-01", ise datetime object banata hai.

# 2️⃣ String to datetime (specific format)
df['DATE'] = pd.to_datetime(df['DATE'], format='%Y-%m-%d')
# ➤ Jab date ka format fix ho to error avoid hota hai.

# 3️⃣ Keep only date part (remove time)
df['DATE'] = df['DATE'].dt.date
# ➤ Sirf YYYY-MM-DD chahiye, time nahi chahiye.

# 4️⃣ Convert date to string
df['DATE'] = df['DATE'].astype(str)
# ➤ Date ko plain string banana ho (e.g., for CSV).

# 5️⃣ Datetime to string in custom format
df['DATE'] = pd.to_datetime(df['DATE']).dt.strftime('%Y-%m-%d')
# ➤ Custom format mein date string chahiye.

# 6️⃣ Include time in string format
df['DATE'] = pd.to_datetime(df['DATE']).dt.strftime('%Y-%m-%d %H:%M:%S')
# ➤ Agar "2024-05-01 00:00:00" format chahiye.

# 7️⃣ Extract year, month, day separately
df['YEAR'] = pd.to_datetime(df['DATE']).dt.year
df['MONTH'] = pd.to_datetime(df['DATE']).dt.month
df['DAY'] = pd.to_datetime(df['DATE']).dt.day
# ➤ Year, Month, Day alag column mein chahiye.

# 8️⃣ Extract weekday name (like Monday)
df['WEEKDAY'] = pd.to_datetime(df['DATE']).dt.day_name()
# ➤ Kaunsa weekday hai, uska naam chahiye.

# 9️⃣ Extract week number of the year
df['WEEK_NUM'] = pd.to_datetime(df['DATE']).dt.isocalendar().week
# ➤ Year ke week number chahiye.

# 10️⃣ Sort by date
df = df.sort_values('DATE')
# ➤ Date ke order mein data chahiye.

# 11️⃣ Filter by date range
mask = (df['DATE'] >= '2024-01-01') & (df['DATE'] <= '2024-12-31')
df_filtered = df.loc[mask]
# ➤ Specific date range ka data nikalna hai.
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Nagesh Agrawal\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\Nagesh Agrawal\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\Nagesh Agrawal\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
# ...
